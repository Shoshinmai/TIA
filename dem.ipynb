# %%
print("hi")
# Out:
# hi

# %%
# from graph import (
#     terminal_graph
# )
import graph

result = graph.terminal_graph.invoke(
    {
        "goal": "show python version",
        "command": "",
        "output": "",
        "error": "",
        "success": False,
        "retry_count": 0
    }
)

print("\n[DONE]")
print(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       1 # from graph import (
#       2 #     terminal_graph
#       3 # )
# ----> 4 import graph
#       5
#       6 result = graph.terminal_graph.invoke(
#       7     {
#
# File d:\AI_dev\CASO\agents\terminal\graph.py:6
#       1 from langgraph.graph import (
#       2     StateGraph,
#       3     END
#       4 )
# ----> 6 from agents.terminal.state import (
#       7     TerminalState
#       8 )
#      10 from agents.terminal.nodes.planner import (
#      11     terminal_planner_node
#      12 )
#      14 from agents.terminal.nodes.validator import (
#      15     validate_command
#      16 )
#
# ModuleNotFoundError: No module named 'agents'

# %%
from IPython.display import Image, display

from graph import terminal_graph

# Assuming 'app' is your compiled LangGraph
display(Image(terminal_graph.get_graph().draw_mermaid_png()))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 from IPython.display import Image, display
#       2
# ----> 3 from graph import terminal_graph
#       4
#       5 # Assuming 'app' is your compiled LangGraph
#       6 display(Image(terminal_graph.get_graph().draw_mermaid_png()))
#
# File d:\AI_dev\CASO\agents\terminal\graph.py:18
#       1 from langgraph.graph import StateGraph, END
#       3 # from agents.terminal.nodes.critic import terminal_critic_node
#       4 # from agents.terminal.nodes.replanner import terminal_replanner_node
#       5 # from agents.terminal.nodes.safety import safety_filter_node
#    (...)     14
#      15 # from agents.terminal.nodes.observer import terminal_observer_node
# ---> 18 from nodes.critic import terminal_critic_node
#      19 from nodes.replanner import terminal_replanner_node
# ...
